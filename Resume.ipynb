# %% [markdown]
# <div style="background-color: #E6F1FF; padding: 30px; border-radius: 15px; border: 3px solid #3366CC; box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);">
#   <h1 style="color: #3366CC; text-align: center; font-size: 32px;">Anuradha Kumari</h1>
#
#   <p style="text-align: center;">
#     <a href="http://www.linkedin.com/in/anuradhanda" style="color: #3366CC; text-decoration: none; margin-right: 10px;">LinkedIn</a> |
#     <span style="color: #3366CC; margin: 0 5px;">551-554-2279</span> |
#     <a href="mailto:avdhanada4498@gmail.com" style="color: #3366CC; text-decoration: none; margin-left: 10px;">avdhanada4498@gmail.com</a> |
#     <span style="color: #3366CC;">GitHub</span>
#   </p>
#
#   <h2 style="color: #3366CC;">EDUCATION</h2>
#
#   <p>
#     <strong>Master of Science in Computer Science, NYIT, NY</strong><br>
#     Expected: Dec 2023
#   </p>
#
#   <p>
#     <strong>Bachelor of Engineering in Information Technology, India</strong>
#   </p>
#
#   <h2 style="color: #3366CC;">SKILLS</h2>
#
#   <p>
#     <strong>Languages:</strong> Python, Java, C, C++,<br>
#     <strong>Database & Cloud Technologies:</strong> MySQL, SQLite, MongoDB, Google Collab<br>
#     <strong>Software Tools, and Frameworks:</strong> Visual Studio Code, Jupyter Notebook, IntelliJ IDEA, Eclipse, Anaconda, Git, Pandas, Numpy, ReactJS, HTML5, CSS3, Figma<br>
#     <strong>Relevant Coursework:</strong> Algorithmic Concepts, Programming Languages, Software Engineering, Advance Machine Learning, Database Systems, Programming for Data Science, Data Visualization, Data Structure
#   </p>
#
#   <h2 style="color: #3366CC;">WORK EXPERIENCE</h2>
#
#   <p>
#     <strong>New York Institute of Technology, Manhattan, New York</strong><br>
#     <em>Research Assistant / May 2022 - Current</em>
#   </p>
#
#   <ul>
#     <li>
#       <strong>Project1-</strong><br>
#       • Assisted a professor and his team of 5 Ph.D. students in Parkinson's research using an AI Robot, KINARM Bi-Exoskeleton<br>
#       • Conducted 20 trials with varying target locations to observe hand movement trajectory, collecting and analyzing data to identify patterns and variations
#     </li>
#
# <li>
#       <strong>Project2-</strong><br>
#       • Assisted Professor and her team of 20 members in Cervical Cancer Research<br>
#       • Improved the accuracy of the machine learning model by 0.15% by using the CNN algorithm<br>
#       • Worked individually and collaboratively to collect and present findings to audiences of varying technical expertise
#     </li>
#
# <li>
#       <strong>Project3-</strong><br>
#       • Collaborated with 2 cross-functional teams to conceptualize and optimize website design using React and MongoDB, Figma<br>
#       • Contributed to the development of website architecture<br>
#       • Participated in weekly project meetings to provide updates on progress and discuss solutions<br>
#       • Ensured alignment of website development with project goals and requirements through close collaboration with design teams
#     </li>
#   </ul>
#
#   <p>
#     <strong>New York Institute of Technology, Manhattan, New York</strong><br>
#     <em>Graduate Assistant / September 2022 - Current</em>
#   </p>
#
#   <ul>
#     <li>
#       • Assist with administrative work, data management, and record-keeping for doctoral and master’s programs for ~ 400<br>
#       • Orchestrated 10+ student events, adhering to budget and timelines through admin collaboration
#     </li>
#   </ul>
#
#   <h2 style="color: #3366CC;">TECHNICAL PROJECTS</h2>
#
#   <p>
#     <strong>NYPD Crime Analysis</strong><br>
#     • Performed EDA and data visualization on a large dataset of over 7.8 million real-time NYC crime reports.<br>
#     • Utilized extensive feature engineering and selection on a dataset resulting in a streamlined set of 13 optimized features<br>
#     • Implemented 7 machine learning models such as Random Forest, and Naive Bayes, for predicting<br>
#     • Conducted hyperparameter tuning and optimization through techniques such as Grid Search and Randomized Search<br>
#     <strong>Technologies:</strong> Python (Pandas, NumPy), EDA, Feature Engineering, Feature Selection, and Machine Learning Algorithms
#   </p>
#
#   <p>
#     <strong>Superstore Sales</strong><br>
#     • Developed 3 dashboards, providing highlighting at least 3 factors affecting superstore sales, based on analysis of a dataset of over 10,000 records<br>
#     • Formulated two novel strategies for launching a new Superstore, backed by 10+ data points and rigorous cost-benefit analysis; suggestions resulted in a 35% increase in sales and 15% higher customer satisfaction score within the first month of opening<br>
#     <strong>Technologies:</strong> Tableau, Machine Learning Algorithms - K-Nearest Neighbor
#   </p>
#
#   <p>
#     <strong>Advanced House Price Prediction</strong><br>
#     • Conducted extensive data analysis and visualization on a ~1500-house dataset to predict housing prices<br>
#     • Employed advanced machine learning techniques, including feature engineering, selection, and hyperparameter tuning, to develop and optimize machine learning models, including Linear Regression, K-Nearest Neighbor, Random Forest, and Naive Bayes, resulting in accurate price predictions<br>
#     <strong>Technologies:</strong> Python (Pandas, NumPy), EDA, Feature Engineering, Feature Selection, and Machine Learning Algorithms
#   </p>
# </div>
